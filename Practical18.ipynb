# %% [markdown]
# <a href="https://colab.research.google.com/github/swastikkmaurya/practical18/blob/main/Practical18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Swastik Maurya
# #25070123114
# #Aim : Exploring Statistical and specialized Data and visualization Techniques

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
np.random.seed(0)

df = pd.DataFrame({

'Category': ['A', 'B', 'C', 'D', 'E'],

'Values': [0, 70, 30, 90, 60],

'Sales': np.random.randint(100, 500, 5),

'Profit': np.random.randint(10, 100, 5)

})

print(df)
# Out:
#   Category  Values  Sales  Profit
# 0        A       0    272      77
# 1        B      70    147      19
# 2        C      30    217      93
# 3        D      90    292      31
# 4        E      60    423      46

# %%
#1. Area Plot
plt.figure()
plt.fill_between(df['Category'], df['Values'], color='green', alpha=0.25)
plt.title('SWASTIK')
plt.xlabel('Category')
plt.ylabel('Values')
plt.show()
print(df)
# Out:
#   Category  Values  Sales  Profit
# 0        A       0    272      77
# 1        B      70    147      19
# 2        C      30    217      93
# 3        D      90    292      31
# 4        E      60    423      46

# %%
import matplotlib.pyplot as plt

import seaborn as sns

sns.set_style("whitegrid") # apply seaborn style

plt.figure(figsize=(7,4))

plt.fill_between (df['Category'], df['Sales'], color='skyblue', alpha=0.5, label='Sales')

plt.fill_between(df['Category'], df['Profit'], color='orange', alpha=0.5, label='Profit')

plt.title("SWASTIK")

plt.xlabel("Category")

plt.ylabel("Values")
plt.legend()

plt.show()

# %%
#2 Pie chart
plt.figure()
plt.pie(df['Values'], labels=df['Category'], autopct='%1.2f%%')
plt.title('SWASTIK')
plt.show()

# %%
#3 Donut Chart

plt.figure()
plt.pie(df['Values'], labels=df['Category'], autopct='%1.1f%%')
centre_circle = plt.Circle ((0,0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title("SWASTIK")
plt.show()

# %%
#4. Boxplot (Outliners Detection)
plt.figure()
sns.boxplot(x=df['Values'])
plt.title('SWASTIK')
plt.show()

# %%
#5. Heatmap (Correlation)
plt.figure()
corr = df[['Sales', 'Profit']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('SWASTIK')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Select only numeric columns
corr = df[['Values', 'Sales', 'Profit']].corr()
plt.figure(figsize=(5,4))
sns.heatmap(corr, annot=True)
plt.title('SWASTIK')
plt.show()

# %%
#bubble plot( 3 variable Chart)
import matplotlib.pyplot as plt
plt.scatter(df['Sales'], df['Profit'], s=df['Values']*10) #Size of Bubbles
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.title('SWASTIK')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x='Sales', y='Profit',
                size='Values', #Bubble Size
                hue='Values',  #Colour
                data=df,
                sizes=(50,300), #Min-Max Size
                palette = 'viridis')

plt.title("SWASTIK")
plt.show()
